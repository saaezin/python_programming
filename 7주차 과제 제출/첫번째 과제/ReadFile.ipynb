# %%
# 2026166390 사애진

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
example1 = "/content/gdrive/My Drive/Colab Notebooks/example1.txt"
file1 = open(example1, "r")

# %%
file1.name
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/example1.txt'

# %%
file1.mode
# Out:
# 'r'

# %%
FileContent = file1.read()
FileContent
# Out:
# 'This is line 1\nThis is line 2\nThis is line 3\n\nThis is line 4'

# %%
print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3
#
# This is line 4

# %%
type(FileContent)
# Out:
# str

# %%
file1.close()

# %%
with open(example1, "r") as file1:
  FileContent = file1.read()
  print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3
#
# This is line 4

# %%
file1.closed
# Out:
# True

# %%
print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3
#
# This is line 4

# %%
with open(example1, "r") as file1:
  print(file1.read(4))
# Out:
# This

# %%
with open(example1, "r") as file1:
  print(file1.read(4))
  print(file1.read(4))
  print(file1.read(7))
  print(file1.read(15))
# Out:
# This
#  is
# line 1
#
# This is line 2

# %%
with open(example1, "r") as file1:
  print(file1.read(16))
  print(file1.read(5))
  print(file1.read(9))
# Out:
# This is line 1
# T
# his i
# s line 2

# %%
with open(example1, "r") as file1:
  print("first line: " + file1.readline())
  print("second line: " + file1.readline())
  print("third line: " + file1.readline())
# Out:
# first line: This is line 1
#
# second line: This is line 2
#
# third line: This is line 3

# %%
with open(example1, "r") as file1:
      i  = 0;
      for line in file1:
         print("lteration", str(i), ": ", line)
         i = i + 1;
# Out:
# lteration 0 :  This is line 1
#
# lteration 1 :  This is line 2
#
# lteration 2 :  This is line 3
#
# lteration 3 :
#
# lteration 4 :  This is line 4

# %%
with open(example1, "r") as file1:
  FileasList = file1.readlines()

# %%
FileasList[0]
# Out:
# 'This is line 1\n'

# %%
FileasList[1]
# Out:
# 'This is line 2\n'

# %%
FileasList[2]
# Out:
# 'This is line 3\n'

# %%
FileasList[3]
# Out:
# '\n'

# %%
FileasList[4]
# Out:
# 'This is line 4'
