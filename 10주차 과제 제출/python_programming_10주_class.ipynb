# %%
# 2026166390 사애진

# %%
result = 0

def adder(num):
  global result
  result += num
  return result

print(adder(3))
print(adder(4))
# Out:
# 3
# 7

# %%
result1 = 0
result2 = 0

def adder1(num):
  global result1
  result1 += num
  return result1

def adder2(num):
  global result2
  result2 += num
  return result2

print(adder1(3))
print(adder1(4))
print(adder2(3))
print(adder2(7))
# Out:
# 3
# 7
# 3
# 10

# %%
class Calculator:
  def __init__(self):
    self.result = 0

  def adder(self, num):
    self.result += num
    return self.result

cal1 = Calculator()
cal2 = Calculator()

print(cal1.adder(3))
print(cal1.adder(4))
print(cal2.adder(3))
print(cal2.adder(7))
# Out:
# 3
# 7
# 3
# 10

# %%
class Service:
  secret = '지구는 4006년에 멸망한다.'

an = Service()

an.secret
# Out:
# '지구는 4006년에 멸망한다.'

# %%
Service.secret

Service.secret = '지구가 4006년에 멸망한다는 사실은 뻥이다.'

print(an.secret)
# Out:
# 지구가 4006년에 멸망한다는 사실은 뻥이다.

# %%
class Service:
  secret = '지구는 4006년에 멸망한다'
  def sum(self, a, b):
    result = a+b
    print("%s + %s = %s이다." % (a,b, result))

an = Service()

an.sum(1,1)
# Out:
# 1 + 1 = 2이다.

# %%
class Service:
  secret = '지구는 4006년에 멸망한다'
  def setname(self, name):
    self.name = name
  def sum(self, a, b):
    result = a+b
    print("%s님, %s + %s = %s입니다." % (self.name, a, b, result))

an = Service()
an.setname("박달도사")
an.sum(1,1)
# Out:
# 박달도사님, 1 + 1 = 2입니다.

# %%
kim = Service()
park = Service()
kim.name = "김정보"
park.name = "박융합"

print(kim.name)
print(park.name)

kim.secret = "비밀은 없다"
print(park.secret)
print(kim.secret)
Service.secret
# Out:
# 김정보
# 박융합
# 지구는 4006년에 멸망한다
# 비밀은 없다
# '지구는 4006년에 멸망한다'

# %%
class Service:
  secret = "지구는 4006년에 멸망한다"
  def __init__(self, name):
    self.name = name
  def sum(self,a,b):
    result = a+b
    print("%s님, %s + %s = %s입니다." % (self.name, a, b, result))

# %%
an = Service("박달도사")
an.sum(1,1)
# Out:
# 박달도사님, 1 + 1 = 2입니다.

# %%
class FourCal:
  pass

a = FourCal()
type(a)
# Out:
# __main__.FourCal

# %%
class FourCal:
  def setdata(self, first, second):
    self.first = first
    self.second = second

a = FourCal()
a.setdata(4,2)
print(a.first)
print(a.second)
# Out:
# 4
# 2

# %%
class FourCal:
  def setdata(self, first, second):
    self.first = first
    self.second = second
  def sum(self):
    result = self.first + self.second
    return result

a = FourCal()
a.setdata(4,2)
print(a.sum())
# Out:
# 6

# %%
class FourCal:
  def setdata(self, first, second):
    self.first = first
    self.second = second
  def sum(self):
    result = self.first + self.second
    return result
  def mul(self):
    result = self.first * self.second
  def sub(self):
    result = self.first - self.second
    return result
  def div(self):
    result = self.first / self.second
    return result

# %%
import random

player1_dice = []
player2_dice = []

for i in range(3):
  player1_dice.append(random.randint(1,6))
  player2_dice.append(random.randint(1,6))

print("Player 1 rolled" + str(player1_dice))
print("Player 2 rolled" + str(player2_dice))

if sum(player1_dice) == sum(player2_dice):
  print('Draw')
elif sum(player1_dice) > sum(player2_dice):
  print("Player 1 wins")
else:
  print("Player 2 wins")
# Out:
# Player 1 rolled[1, 5, 2]
# Player 2 rolled[5, 5, 2]
# Player 2 wins

# %%
from random import randint

class Player:
  def __init__(self):
    self.dice = []

  def roll(self):
    self.dice = []
    for i in range(3):
      self.dice.append(randint(1,6))

  def get_dice(self):
    return self.dice

  player1 = Player()
  player2 = Player()

  player1.roll()
  player2.roll()

  print("Player 1 rolled" + str(player1.get_dice()))
  print("Player 2 rolled" + str(player2.get_dice()))

  if sum(player1.get_dice()) == sum(player2.get_dice()):
    print("Draw!")
  elif sum(player1.get_dice()) > sum(player2.get_dice()):
    print("Player 1 wins!")
  else:
    print("Player 2 wins!")
# Out:
# Player 1 rolled[4, 1, 1]
# Player 2 rolled[4, 5, 5]
# Player 2 wins!

# %%
class Customer(object):
  def __init__(self, name):
    self.name = name

  def set_balance(self, balance=0.0):
    self.balance = balance

  def withdraw(self, amount):
    if amount > self.balance:
      raise RuntimeError('Amount greater than availiable balance.')
    self.balance -=amount
    return self.balance

  def deposit(self, amount):
    self.balance +=amount
    return self.balance
